# %%
import random

print("Type in 'travian_login_sequence()'")

id_1 = "xX_Yul1z4r_Xx"
password_1 = "yurule"
id_2 = "NickelSilv"
password_2 = "100%Nikel"

#edit these values to nerf, buff, change resource amounts, and tribe or troop names
tribes = ["Romans", "Gauls", "Vikings"] # <-- Tribe Names [First group, Second group, Third group]

roma = ["Imperian", "Equites Cesaeris"] # <-- First group troops
roma_attack = [80, 125] # <--- First group attack 
roma_defend = [70, 85]  # <--- First group defence
roma_agility = [30, 40] # <--- First group agility
roma_wheat = [50, 150]  # <--- First group wheat cost
roma_water = [100, 200] # <--- First group water cost

galia = ["Swordman", "Theutaes Thunder"] # <-- Second group troops
galia_attack = [65, 95] # <--- Second group attack
galia_defend = [75, 85] # <--- Second group defence
galia_agility = [40, 60] # <--- Second group agility
galia_wheat = [50, 50] # <--- Second group wheat cost
galia_water = [45, 150] # <--- Second group water cost

viking = ["Clubswinger", "Teutonic Knight"] # <-- First group troops 
viking_attack = [75, 100] # <--- First group attack
viking_defend = [75, 100] # <--- First group defence
viking_agility = [35, 55] # <--- First group agility
viking_wheat = [65, 200] # <--- First group wheat cost
viking_water = [65, 200] # <--- First group water cost

#random resource drop
wheat = random.randrange(500, 30000, 500)
water = random.randrange(1000, 40000, 500)

def travian_login_sequence() :
    print("Login Sequence Activated")
    print("Hello player, please enter your login info.")
    id = input("Input your id : ")
    password = input("Input password : ")
    if id == id_1 and password == password_1 or id == id_2 and password == password_2 :
        print()
        print("status_login = active")
        print()
        print("Welcome back to Travian, " + id)
        print("---------------------------------")
        print("PLAYER TURN")
        print("---------------------------------")
        print("Wheat : ", wheat)
        print("Water : ", water)
        print("---------------------------------")
        print("List of tribes :")
        print()
        print("1. " + tribes[0])
        print("2. " + tribes[1])
        print("3. " + tribes[2])
        print ()
        choices_1 = input("Choose your tribe! '(Type in the name precisely!)'")
        if choices_1 == tribes[0] :
            print()
            print("Troops :")
            print()
            print(roma[0], " | Attack : ", roma_attack[0], " | Defense : ", roma_defend[0], " | Agility : ", roma_agility[0], " | Wheat Cost : ", roma_wheat[0], " | Water Cost : ", roma_water[0])
            print(roma[1], " | Attack : ", roma_attack[1], " | Defense : ", roma_defend[1], " | Agility : ", roma_agility[1], " | Wheat Cost : ", roma_wheat[1], " | Water Cost : ", roma_water[1])
            print()
            print("Input your desired amount of troops from 0 - 100")
            print()
            roma_1_quantity = input("Amount of " + roma[0] + " : ")
            roma_1_resource = roma_1_quantity
            roma_2_quantity = input("Amount of " + roma[1] + " : ")
            roma_2_resource = roma_2_quantity
            if int(roma_1_quantity) > 100 or int(roma_2_quantity) > 100 :
                print()
                print("YOU HAVE CHOSEN TOO MANY TROOPS!")
                print("---------------------------------")
                return travian_login_sequence()
            else :
                wheat_check = wheat - ((roma_wheat[0]*int(roma_1_resource))+(roma_wheat[1]*int(roma_2_resource)))
                water_check = water - ((roma_water[0]*int(roma_1_resource))+(roma_water[1]*int(roma_2_resource)))
                if wheat_check < 0 or water_check < 0 :
                    print()
                    print("NOT ENOUGH RESOURCES TO TRAIN TROOPS!")
                    print("---------------------------------")
                    return travian_login_sequence()
                else :
                    total_attack = float(roma_1_quantity) * float(roma_attack[0] + (0.75*roma_agility[0])) + float(roma_2_quantity) * float(roma_attack[1] + (0.75 * roma_agility[1]))
                    print() 
                    print("Your troop power : " + str(total_attack))
                    print("---------------------------------")
                    print("ENEMY TURN")
                    print("---------------------------------")
                    print("List of tribes :")
                    print()
                    print("1. " + tribes[0])
                    print("2. " + tribes[1])
                    print("3. " + tribes[2])
                    print ()
                    choices_enemy = random.choice(tribes)
                    print ("The enemy has chosen, " + choices_enemy)

                    if choices_enemy == tribes[0] :
                        print()
                        print("Troops :")
                        print()
                        print(roma[0], " | Attack : ", roma_attack[0], " | Defense : ", roma_defend[0], " | Agility : ", roma_agility[0])
                        print(roma[1], " | Attack : ", roma_attack[1], " | Defense : ", roma_defend[1], " | Agility : ", roma_agility[1])
                        print()
                        roma_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[0]) + " : " + str(roma_1_quantity_enemy))
                        roma_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[1]) + " : " + str(roma_2_quantity_enemy))
                        total_defense = float(roma_1_quantity_enemy) * float(roma_defend[0] + (0.75*roma_agility[0])) + float(roma_2_quantity_enemy) * float(roma_defend[1] + (0.75 * roma_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[0])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(roma[0], " : ", roma_1_quantity)
                                print(roma[1], " : ", roma_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    elif choices_enemy == tribes[1] :
                        print()
                        print("Troops :")
                        print()
                        print(galia[0], " | Attack : ", galia_attack[0], " | Defense : ", galia_defend[0], " | Agility : ", galia_agility[0])
                        print(galia[1], " | Attack : ", galia_attack[1], " | Defense : ", galia_defend[1], " | Agility : ", galia_agility[1])
                        print()
                        galia_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[0]) + " : " + str(galia_1_quantity_enemy))
                        galia_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[1]) + " : " + str(galia_2_quantity_enemy))
                        total_defense = float(galia_1_quantity_enemy) * float(galia_defend[0] + (0.75*galia_agility[0])) + float(galia_2_quantity_enemy) * float(galia_defend[1] + (0.75 * galia_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[0])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(roma[0], " : ", roma_1_quantity)
                                print(roma[1], " : ", roma_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    else :
                        print()
                        print("Troops :")
                        print()
                        print(viking[0], " | Attack : ", viking_attack[0], " | Defense : ", viking_defend[0], " | Agility : ", viking_agility[0])
                        print(viking[1], " | Attack : ", viking_attack[1], " | Defense : ", viking_defend[1], " | Agility : ", viking_agility[1])
                        print()
                        viking_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[0]) + " : " + str(viking_1_quantity_enemy))
                        viking_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[1]) + " : " + str(viking_2_quantity_enemy))
                        total_defense = float(viking_1_quantity_enemy) * float(viking_defend[0] + (0.75*viking_agility[0])) + float(viking_2_quantity_enemy) * float(viking_defend[1] + (0.75 * viking_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[0])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(roma[0], " : ", roma_1_quantity)
                                print(roma[1], " : ", roma_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

        elif choices_1 == tribes[1] :
            print()
            print("Troops :")
            print()
            print(galia[0], " | Attack : ", galia_attack[0], " | Defense : ", galia_defend[0], " | Agility : ", galia_agility[0], " | Wheat Cost : ", galia_wheat[0], " | Water Cost : ", galia_water[0])
            print(galia[1], " | Attack : ", galia_attack[1], " | Defense : ", galia_defend[1], " | Agility : ", galia_agility[1], " | Wheat Cost : ", galia_wheat[1], " | Water Cost : ", galia_water[1])
            print()
            print("Input your desired amount of troops from 0 - 100")
            print()
            galia_1_quantity = input("Amount of " + galia[0] + " : ")
            galia_1_resource = galia_1_quantity
            galia_2_quantity = input("Amount of " + galia[1] + " : ")
            galia_2_resource = galia_2_quantity
            if int(galia_1_quantity) > 100 or int(galia_2_quantity) > 100 :
                print()
                print("YOU HAVE CHOSEN TOO MANY TROOPS!")
                print("---------------------------------")
                return travian_login_sequence()
            else :
                wheat_check = wheat - ((galia_wheat[0]*int(galia_1_resource))+(galia_wheat[1]*int(galia_2_resource)))
                water_check = water - ((galia_water[0]*int(galia_1_resource))+(galia_water[1]*int(galia_2_resource)))
                if wheat_check < 0 or water_check < 0 :
                    print()
                    print("NOT ENOUGH RESOURCES TO TRAIN TROOPS!")
                    print("---------------------------------")
                    return travian_login_sequence()
                else :
                    total_attack = float(galia_1_quantity) * float(galia_attack[0] + (0.75*galia_agility[0])) + float(galia_2_quantity) * float(galia_attack[1] + (0.75 * galia_agility[1]))
                    print()
                    print("Your troop power : " + str(total_attack))
                    print("---------------------------------")
                    print("ENEMY TURN")
                    print("---------------------------------")
                    print("List of tribes :")
                    print()
                    print("1. " + tribes[0])
                    print("2. " + tribes[1])
                    print("3. " + tribes[2])
                    print ()
                    choices_enemy = random.choice(tribes)
                    print ("The enemy has chosen, " + choices_enemy)

                    if choices_enemy == tribes[0] :
                        print()
                        print("Troops :")
                        print()
                        print(roma[0], " | Attack : ", roma_attack[0], " | Defense : ", roma_defend[0], " | Agility : ", roma_agility[0])
                        print(roma[1], " | Attack : ", roma_attack[1], " | Defense : ", roma_defend[1], " | Agility : ", roma_agility[1])
                        print()
                        roma_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[0]) + " : " + str(roma_1_quantity_enemy))
                        roma_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[1]) + " : " + str(roma_2_quantity_enemy))
                        total_defense = float(roma_1_quantity_enemy) * float(roma_defend[0] + (0.75*roma_agility[0])) + float(roma_2_quantity_enemy) * float(roma_defend[1] + (0.75 * roma_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(galia[0], " : ", galia_1_quantity)
                                print(galia[1], " : ", galia_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    elif choices_enemy == tribes[1] :
                        print()
                        print("Troops :")
                        print()
                        print(galia[0], " | Attack : ", galia_attack[0], " | Defense : ", galia_defend[0], " | Agility : ", galia_agility[0])
                        print(galia[1], " | Attack : ", galia_attack[1], " | Defense : ", galia_defend[1], " | Agility : ", galia_agility[1])
                        print()
                        galia_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[0]) + " : " + str(galia_1_quantity_enemy))
                        galia_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[1]) + " : " + str(galia_2_quantity_enemy))
                        total_defense = float(galia_1_quantity_enemy) * float(galia_defend[0] + (0.75*galia_agility[0])) + float(galia_2_quantity_enemy) * float(galia_defend[1] + (0.75 * galia_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(galia[0], " : ", galia_1_quantity)
                                print(galia[1], " : ", galia_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    else :
                        print()
                        print("Troops :")
                        print()
                        print(viking[0], " | Attack : ", viking_attack[0], " | Defense : ", viking_defend[0], " | Agility : ", viking_agility[0])
                        print(viking[1], " | Attack : ", viking_attack[1], " | Defense : ", viking_defend[1], " | Agility : ", viking_agility[1])
                        print()
                        viking_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[0]) + " : " + str(viking_1_quantity_enemy))
                        viking_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[1]) + " : " + str(viking_2_quantity_enemy))
                        total_defense = float(viking_1_quantity_enemy) * float(viking_defend[0] + (0.75*viking_agility[0])) + float(viking_2_quantity_enemy) * float(viking_defend[1] + (0.75 * viking_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(galia[0], " : ", galia_1_quantity)
                                print(galia[1], " : ", galia_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

        elif choices_1 == tribes[2] :
            print()
            print("Troops :")
            print()
            print(viking[0], " | Attack : ", viking_attack[0], " | Defense : ", viking_defend[0], " | Agility : ", viking_agility[0], " | Wheat Cost : ", viking_wheat[0], " | Water Cost : ", viking_water[0])
            print(viking[1], " | Attack : ", viking_attack[1], " | Defense : ", viking_defend[1], " | Agility : ", viking_agility[1], " | Wheat Cost : ", viking_wheat[1], " | Water Cost : ", viking_water[1])
            print()
            print("Input your desired amount of troops from 0 - 100")
            print()
            viking_1_quantity = input("Amount of " + viking[0] + " : ")
            viking_1_resource = viking_1_quantity
            viking_2_quantity = input("Amount of " + viking[1] + " : ")
            viking_2_resource = viking_2_quantity
            if int(viking_1_quantity) > 100 or int(viking_2_quantity) > 100 :
                print()
                print("YOU HAVE CHOSEN TOO MANY TROOPS!")
                print("---------------------------------")
                return travian_login_sequence()
            else :
                wheat_check = wheat - ((viking_wheat[0]*int(viking_1_resource))+(viking_wheat[1]*int(viking_2_resource)))
                water_check = water - ((viking_water[0]*int(viking_1_resource))+(viking_water[1]*int(viking_2_resource)))
                if wheat_check < 0 or water_check < 0 :
                    print()
                    print("NOT ENOUGH RESOURCES TO TRAIN TROOPS!")
                    print("---------------------------------")
                    return travian_login_sequence()
                else :
                    total_attack = float(viking_1_quantity) * float(viking_attack[0] + (0.75*viking_agility[0])) + float(viking_2_quantity) * float(viking_attack[1] + (0.75 * viking_agility[1]))
                    print()
                    print("Your troop power : " + str(total_attack))
                    print("---------------------------------")
                    print("ENEMY TURN")
                    print("---------------------------------")
                    print("List of tribes :")
                    print()
                    print("1. " + tribes[0])
                    print("2. " + tribes[1])
                    print("3. " + tribes[2])
                    print ()
                    choices_enemy = random.choice(tribes)
                    print ("The enemy has chosen, " + choices_enemy)

                    if choices_enemy == tribes[0] :
                        print()
                        print("Troops :")
                        print()
                        print(roma[0], " | Attack : ", roma_attack[0], " | Defense : ", roma_defend[0], " | Agility : ", roma_agility[0])
                        print(roma[1], " | Attack : ", roma_attack[1], " | Defense : ", roma_defend[1], " | Agility : ", roma_agility[1])
                        print()
                        roma_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[0]) + " : " + str(roma_1_quantity_enemy))
                        roma_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(roma[1]) + " : " + str(roma_2_quantity_enemy))
                        total_defense = float(roma_1_quantity_enemy) * float(roma_defend[0] + (0.75*roma_agility[0])) + float(roma_2_quantity_enemy) * float(roma_defend[1] + (0.75 * roma_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(viking[0], " : ", viking_1_quantity)
                                print(viking[1], " : ", viking_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    elif choices_enemy == tribes[1] :
                        print()
                        print("Troops :")
                        print()
                        print(galia[0], " | Attack : ", galia_attack[0], " | Defense : ", galia_defend[0], " | Agility : ", galia_agility[0])
                        print(galia[1], " | Attack : ", galia_attack[1], " | Defense : ", galia_defend[1], " | Agility : ", galia_agility[1])
                        print()
                        galia_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[0]) + " : " + str(galia_1_quantity_enemy))
                        galia_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(galia[1]) + " : " + str(galia_2_quantity_enemy))
                        total_defense = float(galia_1_quantity_enemy) * float(galia_defend[0] + (0.75*galia_agility[0])) + float(galia_2_quantity_enemy) * float(galia_defend[1] + (0.75 * galia_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(viking[0], " : ", viking_1_quantity)
                                print(viking[1], " : ", viking_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")

                    else :
                        print()
                        print("Troops :")
                        print()
                        print(viking[0], " | Attack : ", viking_attack[0], " | Defense : ", viking_defend[0], " | Agility : ", viking_agility[0])
                        print(viking[1], " | Attack : ", viking_attack[1], " | Defense : ", viking_defend[1], " | Agility : ", viking_agility[1])
                        print()
                        viking_1_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[0]) + " : " + str(viking_1_quantity_enemy))
                        viking_2_quantity_enemy = random.randrange(1, 100)
                        print("Amount of " + str(viking[1]) + " : " + str(viking_2_quantity_enemy))
                        total_defense = float(viking_1_quantity_enemy) * float(viking_defend[0] + (0.75*viking_agility[0])) + float(viking_2_quantity_enemy) * float(viking_defend[1] + (0.75 * viking_agility[1]))
                        print() 
                        print("Enemy troop defense : " + str(total_defense))
                        print("---------------------------------")
                        print("Type 'attack' to Commence Attack, Type 'retreat' to Return to Basecamp, Type anything 'end' to end game.")
                        start_attack = input()
                        print()
                        if start_attack == "attack" :
                            battle_mode = total_attack - total_defense
                            if battle_mode > 0 :
                                print("YOU HAVE DEFEATED THE ENEMY!")
                                print("---------------------------------")
                                print("User : " + id)
                                print("Clan : " + tribes[1])
                                print("---------------------------------")
                                print("Amount of troops : ")
                                print()
                                print(viking[0], " : ", viking_1_quantity)
                                print(viking[1], " : ", viking_2_quantity)
                                print("---------------------------------")
                                print("Total Attack : " + str(total_attack))
                                print("Total Defense : " + str(total_defense))
                                print("Total Victory : " + str(round(total_attack/total_defense)) + " Rounds ")
                                print("---------------------------------")
                            elif battle_mode == 0 :
                                print("DRAW!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                            else :
                                print("YOU HAVE LOST TO THE ENEMY!")
                                print("Try again!")
                                print("---------------------------------")
                                return travian_login_sequence()
                        elif start_attack == "retreat" :
                            print("---------------------------------")
                            return travian_login_sequence()
                        else :
                            print("---------------------------------")
                            print("The game has been ended. Come back soon!")
        else :
            print()
            print("There are no troops by that name!")
            print("Try again!")
            print("---------------------------------")
            return travian_login_sequence()
    else :
        print()
        login_error = "Denied Access"
        return login_error
# Out:
# Type in 'travian_login_sequence()'

# %%
travian_login_sequence()
# Out:
# Login Sequence Activated
# Hello player, please enter your login info.
# Input your id :  NickelSilv
# Input password :  100%Nikel
# status_login = active
#
# Welcome back to Travian, NickelSilv
# ---------------------------------
# PLAYER TURN
# ---------------------------------
# Wheat :  17000
# Water :  32500
# ---------------------------------
# List of tribes :
#
# 1. Romans
# 2. Gauls
# 3. Vikings
# Choose your tribe! '(Type in the name precisely!)' Gauls
# Troops :
#
# Swordman  | Attack :  65  | Defense :  75  | Agility :  40  | Wheat Cost :  50  | Water Cost :  45
# Theutaes Thunder  | Attack :  95  | Defense :  85  | Agility :  60  | Wheat Cost :  50  | Water Cost :  150
#
# Input your desired amount of troops from 0 - 100
# Amount of Swordman :  100
# Amount of Theutaes Thunder :  100
# Your troop power : 23500.0
# ---------------------------------
# ENEMY TURN
# ---------------------------------
# List of tribes :
#
# 1. Romans
# 2. Gauls
# 3. Vikings
#
# ...
